# %%
# %cd ..
# Out:
# /home/gatanasio/SSPT_IMU
# /home/gatanasio/miniconda3/envs/audio-mae/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os

# %%
from src.visualization.feature_analysis import plot_TSNE, plot_PCA, load_embeddings

# %%
mask = 0.8
embedding_type = 'global_pool'

# %%
embeddings_loc = os.path.join('data', 'EPIC-KITCHENS', 'IMU', 'audio_mae', embedding_type)
filename = f'feature_embeddings_mask({mask}).pkl'

# %%
embeddings, labels = load_embeddings(embeddings_loc, filename, top_labels=5)

# %%
embeddings.max(), embeddings.min()

# %%
len(embeddings)

# %%
plot_TSNE(embeddings, labels, n_components=2, perplexity=12_000, n_iter=5000, random_state=42, s=1)

# %%
plot_PCA(embeddings, labels, n_components=2, random_state=42, s=2)

# %% [markdown]
# ## Global pool

# %%
embedding_type = 'global_pool'
mask=0.5
embeddings_loc = os.path.join('data', 'EPIC-KITCHENS', 'IMU', 'audio_mae', embedding_type)
filename = f'feature_embeddings_mask({mask}).pkl'

# %%
embeddings, labels = load_embeddings(embeddings_loc, filename, top_labels=5)
embeddings.max(), embeddings.min()
# Out:
# (4.238385, -4.178827)

# %%
plot_TSNE(embeddings, labels, n_components=2, perplexity=12_000, n_iter=10_000, random_state=42, s=1, save=True, filename=f'tsne_global_pool_mask{mask}')
# Out:
# /home/gatanasio/SSPT_IMU/src/visualization/feature_analysis.py:56: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(tsne_embeddings_label[:, 0], tsne_embeddings_label[:, 1], s=s, cmap=cmap, label=f'Class {label}')

# %%
plot_PCA(embeddings, labels, n_components=2, random_state=42, s=2, save=True, filename=f'pca_global_pool_mask{mask}')
