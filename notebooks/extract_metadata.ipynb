# %%
import ffmpeg
import os
from pprint import pprint # for printing Python dictionaries in a human-readable way

# read the audio/video file from the command line arguments
media_file = os.path.join('/data', 'EPIC-KITCHENS','P01', 'videos_resized','P01_01.MP4')
# uses ffprobe command to extract all possible metadata from the media file
pprint(ffmpeg.probe(media_file)["streams"])
# Out:
# [{'avg_frame_rate': '60000/1001',
#   'bit_rate': '730564',
#   'bits_per_raw_sample': '8',
#   'chroma_location': 'left',
#   'closed_captions': 0,
#   'codec_long_name': 'H.264 / AVC / MPEG-4 AVC / MPEG-4 part 10',
#   'codec_name': 'h264',
#   'codec_tag': '0x31637661',
#   'codec_tag_string': 'avc1',
#   'codec_time_base': '1001/120000',
#   'codec_type': 'video',
#   'coded_height': 256,
#   'coded_width': 464,
#   'display_aspect_ratio': '16:9',
#   'disposition': {'attached_pic': 0,
#                   'clean_effects': 0,
#                   'comment': 0,
#                   'default': 1,
#                   'dub': 0,
#                   'forced': 0,
#                   'hearing_impaired': 0,
#                   'karaoke': 0,
#                   'lyrics': 0,
#                   'original': 0,
#                   'timed_thumbnails': 0,
#                   'visual_impaired': 0},
#   'duration': '1652.150500',
#   'duration_ts': 99129030,
#   'has_b_frames': 2,
#   'height': 256,
#   'index': 0,
#   'is_avc': 'true',
#   'level': 30,
#   'nal_length_size': '4',
#   'nb_frames': '99030',
#   'pix_fmt': 'yuv420p',
#   'profile': 'High',
#   'r_frame_rate': '60000/1001',
#   'refs': 1,
#   'sample_aspect_ratio': '512:513',
#   'start_pts': 0,
#   'start_time': '0.000000',
#   'tags': {'handler_name': 'VideoHandler', 'language': 'und'},
#   'time_base': '1/60000',
#   'width': 456},
#  {'avg_frame_rate': '0/0',
#   'bit_rate': '128002',
#   'bits_per_sample': 0,
#   'channel_layout': 'stereo',
#   'channels': 2,
#   'codec_long_name': 'AAC (Advanced Audio Coding)',
#   'codec_name': 'aac',
#   'codec_tag': '0x6134706d',
#   'codec_tag_string': 'mp4a',
#   'codec_time_base': '1/48000',
#   'codec_type': 'audio',
#   'disposition': {'attached_pic': 0,
#                   'clean_effects': 0,
#                   'comment': 0,
#                   'default': 1,
#                   'dub': 0,
#                   'forced': 0,
#                   'hearing_impaired': 0,
#                   'karaoke': 0,
#                   'lyrics': 0,
#                   'original': 0,
#                   'timed_thumbnails': 0,
#                   'visual_impaired': 0},
#   'duration': '1652.138667',
#   'duration_ts': 79302656,
#   'index': 1,
#   'max_bit_rate': '128002',
#   'nb_frames': '77444',
#   'profile': 'LC',
#   'r_frame_rate': '0/0',
#   'sample_fmt': 'fltp',
#   'sample_rate': '48000',
#   'start_pts': 0,
#   'start_time': '0.000000',
#   'tags': {'handler_name': 'SoundHandler', 'language': 'und'},
#   'time_base': '1/48000'}]
